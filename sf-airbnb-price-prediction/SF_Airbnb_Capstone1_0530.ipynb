# %%
# Import package
from urllib.request import urlretrieve

# Import pandas
import pandas as pd

# %%
url = 'http://data.insideairbnb.com/united-states/ca/san-francisco/2018-03-04/visualisations/listings.csv'

# %%
df = pd.read_csv(url, sep=',')

# %%
print(df.head())
# Out:
#      id                                               name  host_id  \
# 0   958                Bright, Modern Garden Unit - 1BR/1B     1169
# 1  5858                                 Creative Sanctuary     8904
# 2  7918         A Friendly Room - UCSF/USF - San Francisco    21994
# 3  8014      Newly Remodeled room in big house WIFI market    22402
# 4  8142  Friendly Room Apt. Style -UCSF/USF - San Franc...    21994
#
#           host_name  neighbourhood_group     neighbourhood   latitude  \
# 0             Holly                  NaN  Western Addition  37.769310
# 1  Philip And Tania                  NaN    Bernal Heights  37.745112
# 2             Aaron                  NaN    Haight Ashbury  37.766690
# 3               Jia                  NaN     Outer Mission  37.730746
# 4             Aaron                  NaN    Haight Ashbury  37.764872
#
#     longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0 -122.433856  Entire home/apt    170               1                127
# 1 -122.421018  Entire home/apt    235              30                112
# 2 -122.452505     Private room     65              32                 17
# 3 -122.448409     Private room     60               3                 76
# 4 -122.451828     Private room     65              32                  7
#
#   last_review  reviews_per_month  calculated_host_listings_count  \
# 0  2018-02-26               1.21                               1
# 1  2017-08-06               1.04                               1
# 2  2016-11-21               0.16                               7
# 3  2018-02-16               1.12                               3
# 4  2017-08-12               0.16                               7
#
#    availability_365
# 0               106
# 1               365
# 2               365
# 3                37
# 4               365

# %%
df_bydistrict = df['neighbourhood'].value_counts(dropna=False)

# %%
import matplotlib.pyplot as plt

# %%
df_bydistrict.plot(kind='bar', title = 'listing numbers', alpha = 0.6)

# %%
# Listing number changes with time

# %%
df_roomtype = df['room_type'].value_counts(dropna=False)

# %%
df_roomtype.plot(kind='bar',title = 'Number of listings of different room types', rot=0)

# %%
df.groupby('room_type')['price'].mean().plot(kind='bar', title = 'Price for different room types', rot=0)
# Conclusion: The price for entire homes is highest, and price for shared rooms is lowest.

# %%
df.groupby('room_type')['availability_365'].mean().plot(kind='bar', title = 'Availability for different room types', rot=0)

# %%
df['neighbourhood_group'].value_counts(dropna=False)
# Out:
# NaN    4804
# Name: neighbourhood_group, dtype: int64

# %%
nh_price = df.groupby('neighbourhood')['price'].mean().sort_values(ascending=False)
nh_price.plot(kind='bar')

# %%
# This shows the popularity of different neighbourhoods in San Francisco
nh_avail = df.groupby('neighbourhood')['availability_365'].mean().sort_values(ascending=False)
nh_avail.plot(kind='bar')

# %%
price_avail = pd.concat([nh_price, nh_avail], axis = 1)
price_avail
# Out:
#                              price  availability_365
# Bayview                 127.284553        175.975610
# Bernal Heights          178.662207        123.789298
# Castro/Upper Market     238.920266        124.039867
# Chinatown               241.686275        172.627451
# Crocker Amazon           88.742857        170.685714
# Diamond Heights         177.000000        126.562500
# Downtown/Civic Center   170.197917        115.298611
# Excelsior               114.333333        155.101852
# Financial District      183.761905         81.380952
# Glen Park               235.169811        129.622642
# Golden Gate Park        299.200000        240.400000
# Haight Ashbury          219.825472        155.825472
# Inner Richmond          215.465909        145.818182
# Inner Sunset            196.692308        100.307692
# Lakeshore                96.500000        203.500000
# Marina                  324.942623        171.418033
# Mission                 207.691571        117.906130
# Nob Hill                327.157480        151.803150
# Noe Valley              237.230126        156.146444
# North Beach             217.820000        168.530000
# Ocean View              137.795181        157.734940
# Outer Mission           146.364964        166.328467
# Outer Richmond          174.660194        155.097087
# Outer Sunset            138.895000        135.690000
# Pacific Heights         301.460870        148.060870
# Parkside                244.944444        140.788889
# Potrero Hill            227.591195        136.666667
# Presidio                105.000000        307.000000
# Presidio Heights        419.000000        143.800000
# Russian Hill            364.970874        125.708738
# Seacliff               1059.111111        140.666667
# South of Market         242.071130        123.175732
# Twin Peaks              216.918367        133.510204
# Visitacion Valley       122.826087        115.021739
# West of Twin Peaks      177.424242        177.616162
# Western Addition        321.919355        125.284946

# %%
price_avail.plot(kind = 'scatter', x = 'price', y = 'availability_365')
# Maybe I need to group these neighbourhoods into bigger district.

# %%
df.minimum_nights.value_counts().sort_values()
# Out:
# 8               1
# 17              1
# 13              1
# 9               1
# 85              1
# 185             1
# 100000000       1
# 1000            1
# 140             1
# 120             1
# 1125            1
# 190             1
# 28              1
# 365             1
# 12              1
# 999             2
# 25              2
# 29              3
# 180             3
# 15              3
# 21              4
# 60              5
# 90              5
# 14              6
# 10             10
# 32             19
# 6              32
# 31             53
# 7              65
# 5             178
# 4             237
# 30            657
# 3             872
# 1            1235
# 2            1398
# Name: minimum_nights, dtype: int64

# %%
df.minimum_nights.median()
# Out:
# 2.0

# %%
df[df.minimum_nights<100]['minimum_nights'].plot(kind='hist', bins=20)

# %%
df[df.minimum_nights<50]['minimum_nights'].plot(kind='hist', bins=30)

# %%
df[df.minimum_nights<30]['minimum_nights'].plot(kind='hist', bins=20)

# %%
df[df.minimum_nights<10]['minimum_nights'].plot(kind='hist', bins=10)

# %%
df[df.minimum_nights<35].groupby('minimum_nights')['availability_365'].mean().plot(kind = 'bar')

# %%
df1 = df[df.availability_365 == 0]
df2 = df1[df1['number_of_reviews'] == 0]
df2.shape
# There are 69 entries that are not active listings.
# Out:
# (69, 16)

# %%
df['availability_365'].plot(kind='hist',bins=20)

# %%
df['calculated_host_listings_count'].hist()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4804 entries, 0 to 4803
# Data columns (total 16 columns):
# id                                4804 non-null int64
# name                              4804 non-null object
# host_id                           4804 non-null int64
# host_name                         4776 non-null object
# neighbourhood_group               0 non-null float64
# neighbourhood                     4804 non-null object
# latitude                          4804 non-null float64
# longitude                         4804 non-null float64
# room_type                         4804 non-null object
# price                             4804 non-null int64
# minimum_nights                    4804 non-null int64
# number_of_reviews                 4804 non-null int64
# last_review                       4396 non-null object
# reviews_per_month                 4381 non-null float64
# calculated_host_listings_count    4804 non-null int64
# availability_365                  4804 non-null int64
# dtypes: float64(4), int64(7), object(5)
# memory usage: 600.6+ KB

# %%
import matplotlib.pyplot as plt

# %%
# Visualize the distribution of reviews per month
df[df.reviews_per_month<20]['reviews_per_month'].hist(bins=20)

# %%
# Visualize the distribution of price
df[df.price<1000].price.plot(kind='hist', bins=20)

# %%
df[df.price<600].price.plot(kind='hist', bins=20)

# %%
df.plot(kind='scatter', x='price', y='availability_365',xlim=(0,300), ylim=(0,405))

# %%
entire_home = df[df['room_type'] == 'Entire home/apt']
private_room = df[df['room_type'] == 'Private room']

# %%
entire_home.plot(kind='scatter', x='price', y='availability_365',xlim=(0,300), ylim=(0,400))

# %%
private_room.plot(kind='scatter', x='price', y='availability_365', xlim=(0,300), ylim=(0,400))

# %%
url_cal='http://data.insideairbnb.com/united-states/ca/san-francisco/2018-03-04/data/calendar.csv.gz'

# %%
import pandas as pd

# %%
df_cal = pd.read_csv(url_cal, sep=',',encoding = 'utf-8')

# %%
df_booking = df_cal[df_cal['available']!='f']

# %%
df_cal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1753460 entries, 0 to 1753459
# Data columns (total 4 columns):
# listing_id    int64
# date          object
# available     object
# price         object
# dtypes: int64(1), object(3)
# memory usage: 53.5+ MB

# %%
df_booking[df_booking['listing_id'] == 6938818]
# Out:
#      listing_id        date available   price
# 29      6938818  2018-11-11         t  $69.00
# 30      6938818  2018-11-10         t  $69.00
# 31      6938818  2018-11-09         t  $69.00
# 32      6938818  2018-11-08         t  $69.00
# 33      6938818  2018-11-07         t  $69.00
# 34      6938818  2018-11-06         t  $69.00
# 35      6938818  2018-11-05         t  $69.00
# 36      6938818  2018-11-04         t  $69.00
# 133     6938818  2018-07-30         t  $80.00
# 134     6938818  2018-07-29         t  $88.00
# 135     6938818  2018-07-28         t  $88.00
# 136     6938818  2018-07-27         t  $88.00
# 137     6938818  2018-07-26         t  $84.00
# 138     6938818  2018-07-25         t  $84.00
# 139     6938818  2018-07-24         t  $80.00
# 150     6938818  2018-07-13         t  $88.00
# 151     6938818  2018-07-12         t  $84.00
# 152     6938818  2018-07-11         t  $84.00
# 153     6938818  2018-07-10         t  $84.00
# 154     6938818  2018-07-09         t  $84.00
# 155     6938818  2018-07-08         t  $88.00
# 156     6938818  2018-07-07         t  $88.00
# 157     6938818  2018-07-06         t  $88.00
# 158     6938818  2018-07-05         t  $88.00
# 159     6938818  2018-07-04         t  $88.00
# 160     6938818  2018-07-03         t  $88.00
# 161     6938818  2018-07-02         t  $88.00
# 162     6938818  2018-07-01         t  $88.00
# 344     6938818  2018-11-27         t  $69.00
# 345     6938818  2018-11-26         t  $69.00
# 346     6938818  2018-11-25         t  $69.00
# 347     6938818  2018-11-24         t  $69.00
# 348     6938818  2018-11-23         t  $69.00
# 349     6938818  2018-11-22         t  $69.00
# 350     6938818  2018-11-21         t  $69.00
# 351     6938818  2018-11-20         t  $69.00
# 352     6938818  2018-11-19         t  $69.00
# 353     6938818  2018-11-18         t  $69.00
# 354     6938818  2018-11-17         t  $69.00
# 355     6938818  2018-11-16         t  $69.00
# 356     6938818  2018-11-15         t  $69.00
# 357     6938818  2018-11-14         t  $69.00
# 358     6938818  2018-11-13         t  $69.00
# 359     6938818  2018-11-12         t  $69.00

# %%
df[df['id'] == 6938818]
# Out:
#            id                 name   host_id host_name  neighbourhood_group  \
# 1741  6938818  Best Secret in Town  36381578    Harris                  NaN
#
#      neighbourhood   latitude   longitude     room_type  price  \
# 1741      Seacliff  37.780659 -122.505635  Private room     69
#
#       minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 1741               3                 72  2018-01-20                2.2
#
#       calculated_host_listings_count  availability_365
# 1741                               3                44

# %%
url_rev = 'http://data.insideairbnb.com/united-states/ca/san-francisco/2018-03-04/data/reviews.csv.gz'

# %%
df_rev = pd.read_csv(url_rev, sep=',')

# %%
df_rev.head()
# Out:
#    listing_id     id        date  reviewer_id reviewer_name  \
# 0         958   5977  2009-07-23        15695           Ted
# 1         958   6660  2009-08-03        26145         Simon
# 2         958  11519  2009-09-27        25839         Denis
# 3         958  16282  2009-11-05        33750          Anna
# 4         958  26008  2010-02-13        15416       Venetia
#
#                                             comments
# 0  Our experience was, without a doubt, a five st...
# 1  Returning to San Francisco is a rejuvenating t...
# 2  We were very pleased with the accommodations a...
# 3  We highly recommend this accomodation and agre...
# 4  Holly's place was great. It was exactly what I...

# %%
df_rev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 233230 entries, 0 to 233229
# Data columns (total 6 columns):
# listing_id       233230 non-null int64
# id               233230 non-null int64
# date             233230 non-null object
# reviewer_id      233230 non-null int64
# reviewer_name    233229 non-null object
# comments         233056 non-null object
# dtypes: int64(3), object(3)
# memory usage: 10.7+ MB

# %%
url_listing = 'http://data.insideairbnb.com/united-states/ca/san-francisco/2018-03-04/data/listings.csv.gz'

# %%
df_listing = pd.read_csv(url_listing, sep=',')

# %%
df_listing.head()
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0   958   https://www.airbnb.com/rooms/958  20180303203625   2018-03-04
# 1  5858  https://www.airbnb.com/rooms/5858  20180303203625   2018-03-04
# 2  7918  https://www.airbnb.com/rooms/7918  20180303203625   2018-03-04
# 3  8014  https://www.airbnb.com/rooms/8014  20180303203625   2018-03-04
# 4  8142  https://www.airbnb.com/rooms/8142  20180303203625   2018-03-04
#
#                                                 name  \
# 0                Bright, Modern Garden Unit - 1BR/1B
# 1                                 Creative Sanctuary
# 2         A Friendly Room - UCSF/USF - San Francisco
# 3      Newly Remodeled room in big house WIFI market
# 4  Friendly Room Apt. Style -UCSF/USF - San Franc...
#
#                                              summary  \
# 0  Our bright garden unit overlooks a grassy back...
# 1                                                NaN
# 2  Nice and good public transportation.  7 minute...
# 3  Freshly painted newly done laminate floor with...
# 4  Nice and good public transportation.  7 minute...
#
#                                                space  \
# 0  Newly remodeled, modern, and bright garden uni...
# 1  We live in a large Victorian house on a quiet ...
# 2  Room rental-sunny view room/sink/Wi Fi (inner ...
# 3  The room is recently painted in the color of c...
# 4  Room rental Sunny view Rm/Wi-Fi/TV/sink/large ...
#
#                                          description experiences_offered  \
# 0  Our bright garden unit overlooks a grassy back...                none
# 1  We live in a large Victorian house on a quiet ...                none
# 2  Nice and good public transportation.  7 minute...                none
# 3  Freshly painted newly done laminate floor with...                none
# 4  Nice and good public transportation.  7 minute...                none
#
#                                neighborhood_overview        ...          \
# 0  *Quiet cul de sac in friendly neighborhood *St...        ...
# 1  I love how our neighborhood feels quiet but is...        ...
# 2  Shopping old town, restaurants, McDonald, Whol...        ...
# 3  The neighborhood is very residential, close to...        ...
# 4                                                NaN        ...
#
#   requires_license      license jurisdiction_names instant_bookable  \
# 0                t  STR-0001256  {"SAN FRANCISCO"}                f
# 1                t          NaN  {"SAN FRANCISCO"}                f
# 2                t          NaN  {"SAN FRANCISCO"}                f
# 3                t  STR-0000974  {"SAN FRANCISCO"}                t
# 4                t          NaN  {"SAN FRANCISCO"}                f
#
#   is_business_travel_ready  cancellation_policy  \
# 0                        f             moderate
# 1                        f               strict
# 2                        f               strict
# 3                        f             moderate
# 4                        f               strict
#
#    require_guest_profile_picture require_guest_phone_verification  \
# 0                              f                                f
# 1                              f                                f
# 2                              f                                f
# 3                              f                                f
# 4                              f                                f
#
#    calculated_host_listings_count  reviews_per_month
# 0                               1               1.21
# 1                               1               1.04
# 2                               7               0.16
# 3                               3               1.12
# 4                               7               0.16
#
# [5 rows x 96 columns]

# %%
df_listing.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary',
#        'space', 'description', 'experiences_offered', 'neighborhood_overview',
#        'notes', 'transit', 'access', 'interaction', 'house_rules',
#        'thumbnail_url', 'medium_url', 'picture_url', 'xl_picture_url',
#        'host_id', 'host_url', 'host_name', 'host_since', 'host_location',
#        'host_about', 'host_response_time', 'host_response_rate',
#        'host_acceptance_rate', 'host_is_superhost', 'host_thumbnail_url',
#        'host_picture_url', 'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'street',
#        'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market',
#        'smart_location', 'country_code', 'country', 'latitude', 'longitude',
#        'is_location_exact', 'property_type', 'room_type', 'accommodates',
#        'bathrooms', 'bedrooms', 'beds', 'bed_type', 'amenities', 'square_feet',
#        'price', 'weekly_price', 'monthly_price', 'security_deposit',
#        'cleaning_fee', 'guests_included', 'extra_people', 'minimum_nights',
#        'maximum_nights', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'first_review', 'last_review', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_checkin', 'review_scores_communication',
#        'review_scores_location', 'review_scores_value', 'requires_license',
#        'license', 'jurisdiction_names', 'instant_bookable',
#        'is_business_travel_ready', 'cancellation_policy',
#        'require_guest_profile_picture', 'require_guest_phone_verification',
#        'calculated_host_listings_count', 'reviews_per_month'],
#       dtype='object')

# %%
df_listing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4804 entries, 0 to 4803
# Data columns (total 96 columns):
# id                                  4804 non-null int64
# listing_url                         4804 non-null object
# scrape_id                           4804 non-null int64
# last_scraped                        4804 non-null object
# name                                4804 non-null object
# summary                             4645 non-null object
# space                               4148 non-null object
# description                         4802 non-null object
# experiences_offered                 4804 non-null object
# neighborhood_overview               3655 non-null object
# notes                               3138 non-null object
# transit                             3756 non-null object
# access                              3707 non-null object
# interaction                         3558 non-null object
# house_rules                         3841 non-null object
# thumbnail_url                       0 non-null float64
# medium_url                          0 non-null float64
# picture_url                         4804 non-null object
# xl_picture_url                      0 non-null float64
# host_id                             4804 non-null int64
# host_url                            4804 non-null object
# host_name                           4776 non-null object
# host_since                          4776 non-null object
# host_location                       4769 non-null object
# host_about                          3700 non-null object
# host_response_time                  4410 non-null object
# host_response_rate                  4410 non-null object
# host_acceptance_rate                0 non-null float64
# host_is_superhost                   4776 non-null object
# host_thumbnail_url                  4776 non-null object
# host_picture_url                    4776 non-null object
# host_neighbourhood                  4473 non-null object
# host_listings_count                 4776 non-null float64
# host_total_listings_count           4776 non-null float64
# host_verifications                  4804 non-null object
# host_has_profile_pic                4776 non-null object
# host_identity_verified              4776 non-null object
# street                              4804 non-null object
# neighbourhood                       4804 non-null object
# neighbourhood_cleansed              4804 non-null object
# neighbourhood_group_cleansed        0 non-null float64
# city                                4803 non-null object
# state                               4802 non-null object
# zipcode                             4774 non-null object
# market                              4786 non-null object
# smart_location                      4804 non-null object
# country_code                        4804 non-null object
# country                             4804 non-null object
# latitude                            4804 non-null float64
# longitude                           4804 non-null float64
# is_location_exact                   4804 non-null object
# property_type                       4804 non-null object
# room_type                           4804 non-null object
# accommodates                        4804 non-null int64
# bathrooms                           4781 non-null float64
# bedrooms                            4804 non-null int64
# beds                                4798 non-null float64
# bed_type                            4804 non-null object
# amenities                           4804 non-null object
# square_feet                         115 non-null float64
# price                               4804 non-null object
# weekly_price                        1121 non-null object
# monthly_price                       984 non-null object
# security_deposit                    3675 non-null object
# cleaning_fee                        4327 non-null object
# guests_included                     4804 non-null int64
# extra_people                        4804 non-null object
# minimum_nights                      4804 non-null int64
# maximum_nights                      4804 non-null int64
# calendar_updated                    4804 non-null object
# has_availability                    4804 non-null object
# availability_30                     4804 non-null int64
# availability_60                     4804 non-null int64
# availability_90                     4804 non-null int64
# availability_365                    4804 non-null int64
# calendar_last_scraped               4804 non-null object
# number_of_reviews                   4804 non-null int64
# first_review                        4381 non-null object
# last_review                         4396 non-null object
# review_scores_rating                4370 non-null float64
# review_scores_accuracy              4369 non-null float64
# review_scores_cleanliness           4370 non-null float64
# review_scores_checkin               4368 non-null float64
# review_scores_communication         4369 non-null float64
# review_scores_location              4368 non-null float64
# review_scores_value                 4367 non-null float64
# requires_license                    4804 non-null object
# license                             4192 non-null object
# jurisdiction_names                  4778 non-null object
# instant_bookable                    4804 non-null object
# is_business_travel_ready            4804 non-null object
# cancellation_policy                 4804 non-null object
# require_guest_profile_picture       4804 non-null object
# require_guest_phone_verification    4804 non-null object
# calculated_host_listings_count      4804 non-null int64
# reviews_per_month                   4381 non-null float64
# dtypes: float64(20), int64(14), object(62)
# memory usage: 3.5+ MB

# %%
df_listing.describe()
# Out:
#                  id     scrape_id  thumbnail_url  medium_url  xl_picture_url  \
# count  4.804000e+03  4.804000e+03            0.0         0.0             0.0
# mean   1.125361e+07  2.018030e+13            NaN         NaN             NaN
# std    7.709818e+06  1.148557e+00            NaN         NaN             NaN
# min    9.580000e+02  2.018030e+13            NaN         NaN             NaN
# 25%    3.812677e+06  2.018030e+13            NaN         NaN             NaN
# 50%    1.090908e+07  2.018030e+13            NaN         NaN             NaN
# 75%    1.855375e+07  2.018030e+13            NaN         NaN             NaN
# max    2.359468e+07  2.018030e+13            NaN         NaN             NaN
#
#             host_id  host_acceptance_rate  host_listings_count  \
# count  4.804000e+03                   0.0          4776.000000
# mean   3.357978e+07                   NaN             6.085008
# std    4.601828e+07                   NaN            20.546652
# min    4.600000e+01                   NaN             0.000000
# 25%    3.052907e+06                   NaN             1.000000
# 50%    1.133110e+07                   NaN             2.000000
# 75%    4.414355e+07                   NaN             3.000000
# max    1.762662e+08                   NaN           964.000000
#
#        host_total_listings_count  neighbourhood_group_cleansed  \
# count                4776.000000                           0.0
# mean                    6.085008                           NaN
# std                    20.546652                           NaN
# min                     0.000000                           NaN
# 25%                     1.000000                           NaN
# 50%                     2.000000                           NaN
# 75%                     3.000000                           NaN
# max                   964.000000                           NaN
#
#              ...          number_of_reviews  review_scores_rating  \
# count        ...                4804.000000           4370.000000
# mean         ...                  49.912781             95.787872
# std          ...                  68.268786              5.354162
# min          ...                   0.000000             20.000000
# 25%          ...                   6.000000             94.000000
# 50%          ...                  23.000000             97.000000
# 75%          ...                  66.000000             99.000000
# max          ...                 568.000000            100.000000
#
#        review_scores_accuracy  review_scores_cleanliness  \
# count             4369.000000                4370.000000
# mean                 9.794232                   9.673684
# std                  0.499087                   0.626834
# min                  2.000000                   2.000000
# 25%                 10.000000                   9.000000
# 50%                 10.000000                  10.000000
# 75%                 10.000000                  10.000000
# max                 10.000000                  10.000000
#
#        review_scores_checkin  review_scores_communication  \
# count            4368.000000                  4369.000000
# mean                9.890110                     9.883040
# std                 0.396126                     0.384341
# min                 2.000000                     2.000000
# 25%                10.000000                    10.000000
# 50%                10.000000                    10.000000
# 75%                10.000000                    10.000000
# max                10.000000                    10.000000
#
#        review_scores_location  review_scores_value  \
# count             4368.000000          4367.000000
# mean                 9.631639             9.496909
# std                  0.617341             0.645238
# min                  3.000000             2.000000
# 25%                  9.000000             9.000000
# 50%                 10.000000            10.000000
# 75%                 10.000000            10.000000
# max                 10.000000            10.000000
#
#        calculated_host_listings_count  reviews_per_month
# count                     4804.000000        4381.000000
# mean                         3.766861           2.351408
# std                          8.083173           3.304190
# min                          1.000000           0.020000
# 25%                          1.000000           0.600000
# 50%                          1.000000           1.610000
# 75%                          3.000000           3.330000
# max                         53.000000         110.080000
#
# [8 rows x 34 columns]
